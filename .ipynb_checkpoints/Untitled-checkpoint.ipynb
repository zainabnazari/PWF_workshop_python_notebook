# %%
import scvi
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import scvi
#
# File ~/.local/lib/python3.11/site-packages/scvi/__init__.py:8
#       5 import warnings
#       7 from ._constants import REGISTRY_KEYS
# ----> 8 from ._settings import settings
#      10 # this import needs to come after prior imports to prevent circular import
#      11 from . import data, model, external, utils
#
# File ~/.local/lib/python3.11/site-packages/scvi/_settings.py:9
#       6 from typing import TYPE_CHECKING
#       8 import torch
# ----> 9 from lightning.pytorch import seed_everything
#      10 from rich.console import Console
#      11 from rich.logging import RichHandler
#
# File ~/.local/lib/python3.11/site-packages/lightning/__init__.py:20
#      18 from lightning.fabric.fabric import Fabric  # noqa: E402
# ...

# %%
# !pip install numpy==1.24.4 --force-reinstall
# Out:
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x1547a420a750>: Failed to establish a new connection: [Errno 101] Network is unreachable')': /simple/numpy/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x1547a41c8b10>: Failed to establish a new connection: [Errno 101] Network is unreachable')': /simple/numpy/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x1547a420d3d0>: Failed to establish a new connection: [Errno 101] Network is unreachable')': /simple/numpy/
# ...
